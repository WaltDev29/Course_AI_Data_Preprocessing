# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. 데이터 Load

# %% [markdown]
# ### 1-1. 데이터 Load

# %% [markdown]
# ### 1-2. 컬럼명 수정

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# ### 2-1. 데이터 확인

# %% [markdown]
# ### 2-2. 이상치 제거
